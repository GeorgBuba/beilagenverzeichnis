# %%
import pandas as pd
import re

# %%
df_Beilagen = pd.read_excel('beilagen_Session10_tables.xlsx')
df_Beilagen.head()
# Out:
# C:\Users\georg\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    1  image_00000527.tif   1.1  \
# 0  1  image_00000527.tif     2
# 1  1  image_00000527.tif     3
# 2  1  image_00000527.tif     4
# 3  1  image_00000527.tif  5\n6
# 4  1  image_00000527.tif     7
#
#                              Allerhöchste Thronrede.  \
# 0  Aushebung des Recrutencontingentes im Jahre 1886.
# 1  3 Abänderung des Gesetzes vom 8. März 1885, be...
# 2  4 Intestitionen für das garantirte Netz der Ös...
# 3  Vermehrung des Fahrparks der Staatsbahnen.\n##...
# 4  Beantwortung der Allerhöchsten Thronrede durch...
#
#                                           Unnamed: 4
# 0                                 Regierungsvorlage.
# 1  Antrag des Abge¬\neier¬\nordneten Dr. Men¬\nge...
# 2                     Regierungsvorlage\nund Motive.
# ...
